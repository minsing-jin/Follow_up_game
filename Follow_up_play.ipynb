# %% [markdown]
# <a href="https://colab.research.google.com/github/minsing-jin/Follow_up_game/blob/main/Follow_up_play.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Follow-up program structure
#
# 1. Crawling naver Korean library
# 2. Select machine level
# 2-1. high -> random difficult word
# 2-2. normal -> random word
# 2-3. easy -> easy random words ending with easy following up
# 2-4. impossible -> impossible following up words
#
# cf) machine structure
# - ai
# - random library
#
# 3. UI UX plan
# First no UI UX. If program structure complete, From then, we will programming UI UX with good design

# %% [markdown]
# # Crawling words

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup

def make_words():
  WORDS = []
  url = "https://ko.wiktionary.org/wiki/부록:자주_쓰이는_한국어_낱말_5800"
  r = requests.get(url)
  bs = BeautifulSoup(r.text, 'lxml')
  table = bs.select_one("table.prettytable")
  dds = table.select("tr > td > dl > dd")
  for dd in dds:
    txt = dd.text.replace(" ", "").strip()
    if len(txt) > 1:
      WORDS.append(txt)
  return list(set(WORDS))

print(make_words())
# Out:
# ['풍습', '닮다', '평일', '간접적', '오전', '자취', '방법', '더더욱', '다리', '케첩', '줄곧', '보름', '다방', '얇다', '정도', '상당수', '까먹다', '슈퍼마켓', '좌우', '기여하다', '팔리다', '자라나다', '완성되다', '자연환경', '가깝다', '불이익', '완성', '엄숙하다', '닷새', '철저히', '정거장', '얹다', '영화제', '달려들다', '진출하다', '임시', '피로', '범위', '다니다', '복사', '문학적', '솔직하다', '에너지', '제과점', '이동', '탈출하다', '자세하다', '뽑다', '달력', '고려하다', '생각하다', '새다', '급히', '확실히', '심판', '박수', '썰렁하다', '기원', '지나치다', '티브이', '시일', '그루', '수도', '법원', '신념', '도구', '흰색', '사회주의', '최상', '수학', '주소', '관광버스', '이날', '소중히', '왕비', '적용되다', '행위', '어리석다', '사위', '합격하다', '돼지고기', '지능', '일일이', '거칠다', '따르다', '원피스', '통일하다', '홍수', '끼우다', '확장', '과제', '우승', '수박', '자가용', '대답하다', '그야말로', '발전되다', '한겨울', '일종', '신분', '왼손', '조심스럽다', '치아', '급하다', '작용하다', '여기저기', '주머니', '화장실', '거짓말', '커지다', '틀다', '준비하다', '빨리', '타자기', '진리', '부동산', '녹이다', '유리', '오래되다', '예산', '흥미롭다', '즐거워하다', '시내버스', '몸통', '그리움', '끊임없이', '연장', '임신', '유난히', '논문', '손쉽다', '친절하다', '학위', '서른', '확인', '바이올린', '따로따로', '동서남북', '부러워하다', '까치', '의원', '매너', '접근', '해결되다', '이상하다', '연결', '
# ...

# %% [markdown]
# # Start page

# %%
def start_page():
  print("끝말잇기 시작! 단어를 입력하세요!")
  first_insert_word = str(input())
  while True:
    if len(first_insert_word) >= 0:
      
      return first_insert_word
    else:
      print("단어를 다시 입력하세욧!")

# %% [markdown]
# # Insert word function

# %%
def insert_word(end_word):
  word_book = list(make_words())
  print('함수에서 받은 end_word: ', end_word)
  while True:
    insert_word = str(input())
    print('insert_word: ', insert_word)
    # if insert_word in word_book:
    print('insert_word[0]: ', insert_word[0])
    print('end_word[:len(end_word)-1]: ', end_word[:len(end_word)-1])
    if insert_word[0] == end_word[len(end_word)-1]:
      
      return insert_word

      # else:
      #   print("단어를 다시 입력하세욧!")

    elif insert_word == '포기':
      return 0

    else:
      print("단어를 다시 입력하세욧!")

# %% [markdown]
# # Follow up bot

# %%
import random

def random_easy_bot(word):
  word_book = list(make_words())
  follow_up_words = [i for i in list(make_words()) if i[0] == word[len(word)-1]]
  idx = random.randrange(0,len(follow_up_words))
  
  return follow_up_words[idx]

# %% [markdown]
# # Main function

# %%
#from traitlets.traitlets import Tuple
def main():
  start_word = start_page()
  ai_word = random_easy_bot(start_word)
  print("ai: ", ai_word)
  end_word = ai_word[len(ai_word)-1]
  
  while True:
    print('end_word: ', end_word)
    word = insert_word(end_word)
    ai_word = random_easy_bot(word)
    print("ai: ", ai_word)

    end_word = ai_word[len(ai_word)-1]
    print('end_word: ', end_word)

# %%
main()
# Out:
# 끝말잇기 시작! 단어를 입력하세요!
# 기차
# ai:  차라리
# end_word:  리
# 함수에서 받은 end_word:  리
# 리빈
# insert_word:  리빈
# insert_word[0]:  리
# end_word[:len(end_word)-1]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-39-4150db931fef> in main()
#       9     print('end_word: ', end_word)
#      10     word = insert_word(end_word)
# ---> 11     ai_word = random_easy_bot(word)
#      12     print("ai: ", ai_word)
#      13
#
# <ipython-input-34-18581a3b280b> in random_easy_bot(word)
#       4   word_book = list(make_words())
#       5   follow_up_words = [i for i in list(make_words()) if i[0] == word[len(word)-1]]
# ----> 6   idx = random.randrange(0,len(follow_up_words))
#       7
#       8   return follow_up_words[idx]
#
# /usr/lib/python3.8/random.py in randrange(self, start, stop, step, _int)
# ...

# %% [markdown]
# # Design GUI

# %%
from tkinter import *

tk = Tk() 
# 2. 텍스트 표시
label = Label(tk,text='Hello World!') 
# 3. 레이블 배치 실행
label.pack()
# 4. 메인루프 실행
tk.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-795e13948997> in <module>
#       1 from tkinter import *
#       2
# ----> 3 tk = Tk()
#       4 # 2. 텍스트 표시
#       5 label = Label(tk,text='Hello World!')
#
# /usr/lib/python3.8/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2259                 baseName = baseName + ext
#    2260         interactive = 0
# -> 2261         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2262         if useTk:
#    2263             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'    # tell X clients to use our virtual DISPLAY :1.0.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 785 kB of archives.
# After this operation, 2,271 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.13 [785 kB]
# Fetched 785 kB in 1s (1,437 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.13_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.13) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.13) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# 해결할것들: 동음 이의어, 두음법칙,
