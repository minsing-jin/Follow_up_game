# %% [markdown]
# <a href="https://colab.research.google.com/github/minsing-jin/Follow_up_game/blob/main/Follow_up_play.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Follow-up program structure
#
# 1. Crawling naver Korean library
# 2. Select machine level
# 2-1. high -> random difficult word
# 2-2. normal -> random word
# 2-3. easy -> easy random words ending with easy following up
# 2-4. impossible -> impossible following up words
#
# cf) machine structure
# - ai
# - random library
#
# 3. UI UX plan
# First no UI UX. If program structure complete, From then, we will programming UI UX with good design

# %% [markdown]
# cf) Colab can't apply tkinter. So we will use flask using goorm ide.

# %% [markdown]
# # Crawling words

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=4fec747b65a65bc07aebaba84e748792f11705701a96222c9ead51618e655e0f
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
import requests
from bs4 import BeautifulSoup

def make_words():
  WORDS = []
  url = "https://ko.wiktionary.org/wiki/부록:자주_쓰이는_한국어_낱말_5800"
  r = requests.get(url)
  bs = BeautifulSoup(r.text, 'lxml')
  table = bs.select_one("table.prettytable")
  dds = table.select("tr > td > dl > dd")
  for dd in dds:
    txt = dd.text.replace(" ", "").strip()
    if len(txt) > 1:
      WORDS.append(txt)
  return list(set(WORDS))

print(make_words())
# Out:
# ['소중하다', '몰려들다', '알리다', '카레', '구르다', '정치', '탁월하다', '노선', '보수', '악수', '이미', '안과', '농민', '보람', '작가', '요새', '장차', '옆방', '재주', '겁나다', '부장', '아랫사람', '빠져나가다', '브랜드', '흐리다', '적응하다', '거짓말', '열리다', '거부하다', '지혜', '오랫동안', '조상', '만들다', '가입', '실망하다', '선배', '그럼', '뛰놀다', '평균', '가르침', '집안', '연장', '단풍', '예측하다', '별명', '또는', '매달', '기법', '승리하다', '방해', '중단되다', '진행', '회의', '무의미하다', '문구', '과정', '여기저기', '도대체', '뵈다', '미워하다', '비행기', '연간', '사귀다', '옆구리', '독립', '쓴맛', '스웨터', '애쓰다', '가려지다', '바깥', '여행사', '대체로', '최근', '분명하다', '들어서다', '피로하다', '장수', '의하다', '소재', '문학', '시대', '보내다', '추진', '치과', '가난', '대화하다', '바이올린', '학위', '북부', '속삭이다', '자신감', '신념', '추진하다', '외출', '머리말', '약국', '천재', '손녀', '듯하다', '음식점', '정면', '이제', '동물원', '귀엽다', '최후', '발음하다', '귓속', '명의', '너희', '시집', '우정', '마르다', '커피', '검은색', '저리', '양복', '담당', '그룹', '이웃집', '장사', '신세', '서양', '끼다', '아마', '정신없이', '방지하다', '전용', '친척', '크림', '채우다', '말씀', '생활환경', '강사', '중단', '상자', '기도', '해마다', '불빛', '학부모', '지각', '정답', '예보', '식사하다', '시스템', '한눈', '재활용', '형제', '운동복', '완성되다', '원인', '돌보다', '역사상', '발전하다', '집안일', '야채', '그래서', '퇴근하다', '들이마시다', '사랑', '소속', '가까워지다', '노래방', '뒷모습', '실제로', '엘리베이터', '치약', '레몬', '위대하다', '채널', '항상', '목적', '미터', '출현하다', '나뭇가지', '사회', '신선하다', '끼어들다', '전체적', '식량', '분야', '그전', '공공', '제시하다', '아저씨', '피곤하다', '모니터', '오해', '부엌', '이데올로기', '얼음', '피로', '제작하다', '영상', '부친', '연구자', '이십', '연기자', '수리하다', '안팎', '사회자', '어린아이', '경치', '급증하다', '사랑스럽다', '센티미터', '이상하다', '문화', '우리', '속담', '가치', '나타내다', '개국', '바닥', '집다', '가끔', '의자', '대가', '구분', '한참', '보너스', '솟다', '시월', '수많다', '약혼녀', '결혼', '자리', '바꾸다', '열쇠', '외모', '아마도', '손질하다', '종소리', '고르다', '지름길', '또다시', '돌아오다', '대략', '추가되다', '월급', '관습', '담다', '벗다', '이혼', '언론', '손쉽다', '여름철', '시험', '어쨌든', '검토', '새로', '못지않다', '말없이', '칠월', '시끄럽다', '지워지다', '신체', '고급', '절대적', '곧이어', '매년', '짜다', '놓다', '신분', '근무하다', '바나나', '빌리다', '앞길', '다섯', '투표', '여기다', '불평', '일요일', '깨뜨리다', '내일', '구체적', '근로', '다행히', '집중되다', '뒤지다', '무지개', '좁다', '분량', '등등', '일회용품', '대답하다', '녀석', '떠오르다', '선호하다', '잔디밭', '제한', '감정적', '다짐하다', '방금', '결혼하다', '신문지', '빨래', '짓다', '며칠', '골목', '이끌다', '부정', '만남', '갚다', '오염되다', '토대', '갈아입다', '다녀오다', '가뭄', '소중히', '팝송', '코미디', '액세서리', '수영장', '동쪽', '붙들다', '잡아먹다', '묘사하다', '복잡하다', '군사', '야구장', '책임자', '번역하다', '통과', '돼지고기', '그리고', '마지막', '연예인', '땅속', '가슴속', '손뼉', '관계', '공해', '변하다', '오로지', '심다', '그저께', '포도', '높다', '납득하다', '서늘하다', '초원', '붙잡히다', '효도하다', '탈출하다', '쓰러지다', '아래쪽', '좋다', '기도하다', '쓰이다', '열다', '요약하다', '착각하다', '임무', '반죽', '방송국', '원하다', '범죄', '수면', '문화적', '벌리다', '끌리다', '코드', '단체', '올라오다', '가라앉다', '주차하다', '조각', '되살리다', '살아오다', '국회', '태어나다', '답변', '군대', '치료', '갖가지', '튀다', '가수', '탁자', '경비', '식사', '꺾다', '인간관계', '닦다', '큰절', '슬쩍', '직선', '동물', '맞추다', '옳다', '안타깝다', '연두색', '있다(보조동사)', '결과적', '옮기다', '잠깐', '종업원', '입장', '과외', '칠하다', '메뉴', '연결하다', '전후', '건너', '계산하다', '넓히다', '특별하다', '소풍', '형수', '금년', '교장', '윗사람', '상표', '누나', '보수적', '유적', '주장', '발달하다', '무렵', '빨다', '시도하다', '술병', '봉사하다', '아무리', '대합실', '민주주의', '교훈', '임신하다', '배우', '길다', '무궁화', '시댁', '출입국', '애인', '친정', '부대', '부르다', '버터', '추가', '밤중', '식초', '라면', '대사', '월요일', '초반', '명령어', '지난주', '순위', '파악하다', '지켜보다', '이따가', '활기', '맡다', '호선', '주년', '관리', '낯설다', '키스', '장점', '양보하다', '지진', '인재', '앓다', '평화', '아깝다', '끊기다', '공간', '팔월', '허용하다', '책임지다', '그립다', '놀이터', '그리하여', '금지', '매번', '감상하다', '서다', '자세히', '소망', '운명', '심리적', '합하다', '관심', '손길', '가짜', '되돌아오다', '호실', '기념', '발전되다', '덮이다', '구경하다', '되돌리다', '웃음소리', '인제', '외로움', '여우', '세우다', '부처', '문법', '먹히다', '미사일', '개구리', '용서하다', '호박', '보도', '곤란하다', '참조', '아름답다', '잃다', '균형', '말리다', '무엇', '귀중하다', '재밌다', '형편', '천장', '통계', '불평등하다', '이름', '판단', '다행', '마사지', '품질', '분석하다', '자다', '구성되다', '지적', '큰어머니', '신인', '통일하다', '만만하다', '접촉', '약속', '숫자', '일행', '피시', '심심하다', '아침', '면적', '야외', '출퇴근', '안녕하다', '노랗다', '대개', '해당되다', '따라서', '알다', '실천', '현지', '나뉘다', '지우다', '발자국', '쏟아지다', '백색', '걸치다', '부동산', '만족스럽다', '내년', '건축', '모으다', '재생', '조화되다', '체험', '씨름', '피부', '장미', '성적', '받아들이다', '가하다', '아냐', '속도', '환갑', '각국', '처음', '의외로', '무섭다', '터미널', '억울하다', '혈액', '그냥', '발걸음', '인원', '상하다', '숨다', '우려', '한쪽', '이자', '동아리', '종일', '음료', '요즈음', '반대', '팬티', '낚시', '꼽히다', '사월', '피해', ...

# %% [markdown]
# # Start page

# %%
def start_page():
  print("끝말잇기 시작! 단어를 입력하세요!")
  first_insert_word = str(input())
  while True:
    if len(first_insert_word) >= 0:

      return first_insert_word
    else:
      print("단어를 다시 입력하세욧!")

# %% [markdown]
# # Insert word function

# %%
def insert_word(end_word):
  word_book = list(make_words())
  print('함수에서 받은 end_word: ', end_word)
  while True:
    insert_word = str(input())
    print('insert_word: ', insert_word)
    # if insert_word in word_book:
    print('insert_word[0]: ', insert_word[0])
    print('end_word[:len(end_word)-1]: ', end_word[:len(end_word)-1])
    if insert_word[0] == end_word[len(end_word)-1]:

      return insert_word

      # else:
      #   print("단어를 다시 입력하세욧!")

    elif insert_word == '포기':
      return 0

    else:
      print("단어를 다시 입력하세욧!")

# %% [markdown]
# # Follow up bot

# %%
import random

def random_easy_bot(word):
  word_book = list(make_words())
  follow_up_words = [i for i in list(make_words()) if i[0] == word[len(word)-1]]
  idx = random.randrange(0,len(follow_up_words))

  return follow_up_words[idx]

# %% [markdown]
# # Main function

# %%
#from traitlets.traitlets import Tuple
def main():
  start_word = start_page()
  ai_word = random_easy_bot(start_word)
  print("ai: ", ai_word)
  end_word = ai_word[len(ai_word)-1]

  while True:
    print('end_word: ', end_word)
    word = insert_word(end_word)
    ai_word = random_easy_bot(word)
    print("ai: ", ai_word)

    end_word = ai_word[len(ai_word)-1]
    print('end_word: ', end_word)

# %%
main()
# Out:
# 끝말잇기 시작! 단어를 입력하세요!
# ai:  어지럽다
# end_word:  다
# 함수에서 받은 end_word:  다
# insert_word:  다우
# insert_word[0]:  다
# end_word[:len(end_word)-1]:
# ai:  우수하다
# end_word:  다
# end_word:  다
# 함수에서 받은 end_word:  다
# insert_word:  다행
# insert_word[0]:  다
# end_word[:len(end_word)-1]:
# ai:  행동
# end_word:  동
# end_word:  동
# 함수에서 받은 end_word:  동
# insert_word:  동사
# insert_word[0]:  동
# end_word[:len(end_word)-1]:
# ai:  사건
# end_word:  건
# end_word:  건
# 함수에서 받은 end_word:  건
# insert_word:  건건
# insert_word[0]:  건
# end_word[:len(end_word)-1]:
# ai:  건강하다
# end_word:  다
# end_word:  다
# 함수에서 받은 end_word:  다

# %% [markdown]
# 해결할것들: 동음 이의어, 두음법칙,
